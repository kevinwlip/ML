# %% [markdown]
# ### Random Walk

# %%
# https://www.youtube.com/watch?v=BfS2H1y6tzQ

# %%
# Random Functions
# random.random
# random.uniform
# random.normalvariate
# random.randint
# random.choice

# %%
import random

# %%
def random_walk(n):
    """Return coordinates after 'n' block random walk."""
    x = 0
    y = 0
    
    for i in range(n):
        step = random.choice(['N', 'S', 'E', 'W'])
        if step == 'N':
            y = y + 1
        elif step == 'S':
            y = y - 1
        elif step == 'E':
            x = x + 1
        else:
            x = x - 1
    return (x, y)

# %%
for i in range(25):
    walk = random_walk(10)
    print(walk, "Distance from home = ", abs(walk[0]) + abs(walk[1]))
# Out:
# (0, 0) Distance from home =  0
# (1, 3) Distance from home =  4
# (1, 1) Distance from home =  2
# (-1, -1) Distance from home =  2
# (2, -4) Distance from home =  6
# (1, -1) Distance from home =  2
# (0, 0) Distance from home =  0
# (0, 4) Distance from home =  4
# (-2, 2) Distance from home =  4
# (-4, -2) Distance from home =  6
# (-4, 0) Distance from home =  4
# (0, -2) Distance from home =  2
# (2, 0) Distance from home =  2
# (2, 0) Distance from home =  2
# (-3, 1) Distance from home =  4
# (2, 0) Distance from home =  2
# (1, 3) Distance from home =  4
# (1, -5) Distance from home =  6
# (2, -4) Distance from home =  6
# (1, -3) Distance from home =  4
# (-2, 0) Distance from home =  2
# (2, -2) Distance from home =  4
# (1, 1) Distance from home =  2
# (-1, -3) Distance from home =  4
# (2, 4) Distance from home =  6

# %%
def random_walk_2(n):
    """Return coordinates after 'n' block random walk."""
    x, y = 0, 0
    
    for i in range(n):
        (dx, dy) = random.choice([(0, 1), (0, -1), (1, 0), (-1, 0)])
        x += dx
        y += dy
    return (x, y)

# %%
for i in range(25):
    walk = random_walk_2(10)
    print(walk, "Distance from home = ", abs(walk[0]) + abs(walk[1]))
# Out:
# (0, 2) Distance from home =  2
# (2, 4) Distance from home =  6
# (-2, -2) Distance from home =  4
# (2, 0) Distance from home =  2
# (1, -5) Distance from home =  6
# (1, 3) Distance from home =  4
# (0, -6) Distance from home =  6
# (-2, -2) Distance from home =  4
# (-2, 0) Distance from home =  2
# (1, -3) Distance from home =  4
# (3, 3) Distance from home =  6
# (-2, 4) Distance from home =  6
# (-3, 3) Distance from home =  6
# (-1, 1) Distance from home =  2
# (0, 0) Distance from home =  0
# (0, -2) Distance from home =  2
# (0, 0) Distance from home =  0
# (0, 0) Distance from home =  0
# (-2, 0) Distance from home =  2
# (-1, 1) Distance from home =  2
# (-3, 3) Distance from home =  6
# (-2, -2) Distance from home =  4
# (-1, 1) Distance from home =  2
# (-4, 0) Distance from home =  4
# (-1, 1) Distance from home =  2

# %%
# Monte Carlo Simulation

number_of_walks = 20000
for walk_length in range(1, 31):
    no_transport = 0   # Number of walks 4 or fewer blocks from home
    for i in range(number_of_walks):
        (x, y) = random_walk_2(walk_length)
        distance = abs(x) + abs(y)
        if distance <= 4:
            no_transport += 1
    no_transport_percentage = float(no_transport) / (number_of_walks)
    print("Walk size = ", walk_length, " / % of no transport = ", 100*no_transport_percentage)
# Out:
# Walk size =  1  / % of no transport =  100.0
# Walk size =  2  / % of no transport =  100.0
# Walk size =  3  / % of no transport =  100.0
# Walk size =  4  / % of no transport =  100.0
# Walk size =  5  / % of no transport =  87.805
# Walk size =  6  / % of no transport =  94.03
# Walk size =  7  / % of no transport =  76.33
# Walk size =  8  / % of no transport =  86.42999999999999
# Walk size =  9  / % of no transport =  67.235
# Walk size =  10  / % of no transport =  79.2
# Walk size =  11  / % of no transport =  59.63
# Walk size =  12  / % of no transport =  73.185
# Walk size =  13  / % of no transport =  53.38
# Walk size =  14  / % of no transport =  67.455
# Walk size =  15  / % of no transport =  49.74
# Walk size =  16  / % of no transport =  62.019999999999996
# Walk size =  17  / % of no transport =  44.925
# Walk size =  18  / % of no transport =  58.345
# Walk size =  19  / % of no transport =  40.675
# Walk size =  20  / % of no transport =  54.37499999999999
# Walk size =  21  / % of no transport =  37.875
# Walk size =  22  / % of no transport =  50.824999999999996
# Walk size =  23  / % of no transport =  35.53
# Walk size =  24  / % of no transport =  48.405
# Walk size =  25  / % of no transport =  33.39
# Walk size =  26  / % of no transport =  45.57
# Walk size =  27  / % of no transport =  30.869999999999997
# Walk size =  28  / % of no transport =  43.21
# Walk size =  29  / % of no transport =  29.535
# Walk size =  30  / % of no transport =  41.78
